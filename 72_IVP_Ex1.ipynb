# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread(r'D:\Malathi\SEM_6\IVP\image_new.jpeg')

# %%
plt.imshow(img)

# %%
image=cv2.imread(r'D:\Malathi\SEM_6\IVP\image_new.jpeg')

# Convert to Grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

_, th2 = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
#plt.imshow(th2)

# Use a copy of your image e.g. edged.copy(), since findContours alters the image
contours, hierarchy = cv2.findContours(th2, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)

# Draw all contours, note this overwrites the input image (inplace operation)
# Use '-1' as the 3rd parameter to draw all
cv2.drawContours(image, contours, -1, (255,255,255), thickness = 0)
plt.imshow(image)

# %%
import cv2

def denoise_image(input_image_path, output_image_path, h=27, templateWindowSize=7, searchWindowSize=21):
    # Read the image
    image = cv2.imread(input_image_path)

    # Convert the image to grayscale (if it's a color image)
    if len(image.shape) == 3:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Denoise the image using the Non-Local Means Denoising algorithm
    denoised_image = cv2.fastNlMeansDenoising(image, None, h=h, templateWindowSize=templateWindowSize, searchWindowSize=searchWindowSize)

    # Save the denoised image
    cv2.imwrite(output_image_path, denoised_image)

# Example usage
input_image_path = 'D:\Malathi\SEM_6\IVP\image_new.jpeg'
output_image_path = 'image_new_1.jpeg'
denoise_image(input_image_path, output_image_path)

# %%
image=cv2.imread(r'D:\Malathi\SEM_6\IVP\image_new.jpeg')

_, th2 = cv2.threshold(image, 200, 255, cv2.THRESH_BINARY_INV)
th2=cv2.cvtColor(th2,cv2.COLOR_BGR2GRAY)
th2=np.uint8(th2)

contours, hierarchy = cv2.findContours(th2, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)
cv2.drawContours(image, contours, -1, (0,0,0), thickness = 0)
plt.imshow(image)

# %%
result=cv2.bitwise_and(img,img,mask=th2)
plt.imshow(result)

# %%
def segment_with_histogram(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, thresholded = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    return thresholded

# %%
img = cv2.imread("D:\Malathi\SEM_6\IVP\image_new.jpeg")

# %%
img2 = segment_with_histogram(img)
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))

# %%
image = cv2.imread("D:\Malathi\SEM_6\IVP\image_new.jpeg")

_, th2 = cv2.threshold(image, 200, 255, cv2.THRESH_BINARY_INV)
th2=cv2.cvtColor(th2,cv2.COLOR_BGR2GRAY)
th2=np.uint8(th2)

contours, hierarchy = cv2.findContours(th2, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)
cv2.drawContours(image, contours, -1, (0,0,0), thickness = 0)
plt.imshow(image)

# %%
_, th2 = cv2.threshold(image, 200, 255, cv2.THRESH_BINARY_INV)
th2=cv2.cvtColor(th2,cv2.COLOR_BGR2GRAY)
th2=np.uint8(th2)

# %%
result=cv2.bitwise_and(img,img,mask=th2)
plt.imshow(result)
